# %% [markdown]
# # AerE 361 - Professor Nelson
# ## Lecture 5 - In-class Notebook
# ## Operating Systems
#
# ### Student Name here

# %% [markdown]
# # Turn in instructions
#
# 1. Make sure you put your name in the block above
# 2. Complete and answer questions in this notebook
# 3. Make sure you run all code in this notebook
# 4. Go to File->Download As->.html
#
# Upload the HTML file to the assignment to Canvas. Only HTML submissions will be accepted. Any other submission will recieve a zero.

# %% [markdown]
# ## Embedded systems in-class
# <center><img src="https://images.squarespace-cdn.com/content/v1/5efeb5d46e5e211eaa9dd6fd/520bdf58-9c6a-472e-adde-232720e5f398/IMG_1568.jpg" width="800"/></center>
#
# In the box below, put the name of at least 3 items in the picture that has an embedded system in it.

# %% [markdown]
# ## Operating system commands in Python
# Just about any programming language can usually access various aspects of the operating system. In Python, we can easily interact with the operating system using the OS and platform modules. To start, let's import both os and platform. Make sure you run the code below or the rest of the code will not work.

# %%
import os
import platform

# %% [markdown]
# Let's start with something simple, have Python read back what operating system it is currently running on. Put the following code in the box below.
#
# ```Python
# platform.uname()
# ```

# %% [markdown]
# After you run the block above, you should see something that identifies your operating system, type of hardware and even the CPU type. Now, let's also see what version of Python you are running, put the following code in the block below.
#
# ```Python
# platform.python_version()
# ```
#
# As a note on this, you should probably be running a version of Python that is version 3.8 or higher. Most of you should be 3.9 or 3.10.

# %% [markdown]
# This is great, but it is often useful to work with the filesystem and this is most often what you want Python or any other programming language work with. This can be to read and write files and even create files and folders. For now, let's find out what the file path we have. We can use the following to determine the currently directory structure.
#
# ```Python
# os.getcwd()
# ```
#
# Note that this will look different from computer to computer. It will depend if you are running Windows or a NIX OS llike MacOS or Linux. It will also change based on where you are running this notebook.

# %% [markdown]
# Let's see who is using the computer. Type in the following:
#
# ```Python
# os.getlogin()
# ```

# %% [markdown]
# We can also list what files and folders we have in our currently directory. Type in the following in the box below.
#
# ```Python
# os.listdir()
# ```

# %% [markdown]
# Ok, let's combine some stuff we can use the following command to make a directory.
#
# ```Python
# os.mkdir(path = "path location")
# ```
#
# We want to make a new directory in the current directory we are in. We need to pass the full path of where we are currently. We could type this in manually, but then that wouldn't work in other setups where the location might change. Instead, we can get our current directory using the command we just used above. Now, we need to add the name of the directory we just called from the listdir command. That can easily be done by using the "+" to concatanate the strings. Use os.mkdir to make a new folder in this current folder called "AerE361".
#
# Hint: You will need an additional "/" before the name of the folder name you are trying to create.

# %% [markdown]
# Let's make sure this works. Run the code block below after running the one above. You should see your folder now listed.

# %%
os.listdir()

# %% [markdown]
# That's it for this in-class notebook. Make sure your name is on it and save it as HTML. IN Jupyter Notebook this is File->Download as->HTML. If you are using VS Code, then it is
#
# ![Screenshot%202023-01-30%20at%2011.49.18%20PM.png](attachment:Screenshot%202023-01-30%20at%2011.49.18%20PM.png)

# %% [markdown]
# ![Screenshot%202023-01-30%20at%2011.49.38%20PM.png](attachment:Screenshot%202023-01-30%20at%2011.49.38%20PM.png)
